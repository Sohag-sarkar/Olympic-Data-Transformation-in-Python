# %%
# import necessary libraries for data analysis
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load Datasets

athlete= pd.read_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\Olympic Data\\athlete_events.csv")
Region= pd.read_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\Olympic Data\\noc_regions.csv")
pop=  pd.read_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\Olympic Data\\world_pop.csv")
GDP= pd.read_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\Olympic Data\\world_gdp.csv")

# %%
# display datasets

pd.set_option("display.max_rows",None)
athlete.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
# Fill null values in Medal

athlete.fillna(
{"Medal": 0 }, inplace=True
)
athlete.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
# Finding null value percentage

for col in athlete.columns:
    missing_pct = np.mean(athlete[col].isnull())
    print("{} - {}".format(col, missing_pct))
# Out:
# ID - 0.0
# Name - 0.0
# Sex - 0.0
# Age - 0.0
# Height - 0.0
# Weight - 0.0
# Team - 0.0
# NOC - 0.0
# Games - 0.0
# Year - 0.0
# Season - 0.0
# City - 0.0
# Sport - 0.0
# Event - 0.0
# Medal - 0.0

# %%
sns.heatmap(athlete.isnull())
# Out:
# <AxesSubplot:>

# %%
# Populate Age, height and weight data in athlete

athlete[athlete["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
athlete["Sport"].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
athlete.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
sns.distplot(athlete["Age"],bins=10)
# Out:
# C:\Users\VOID HEAD\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(athlete["Age"])
# Out:
# C:\Users\VOID HEAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(athlete["Height"])
# Out:
# C:\Users\VOID HEAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(athlete["Weight"])
# Out:
# C:\Users\VOID HEAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Weight'>

# %%
plt.scatter(x="Weight", y= "Sport", data = athlete)

# %%
# Impute missing data 

athlete.fillna(
{
    "Age":25,
    "Height":175,
    "Weight": 70
}, inplace= True)

# %%
athlete.describe()
# Out:
#                   ID            Age        Height         Weight  \
# count  271116.000000  271116.000000  271116.00000  271116.000000
# mean    68248.954396      25.537438     175.26374      70.539500
# std     39022.286345       6.281690       9.27917      12.578184
# min         1.000000      10.000000     127.00000      25.000000
# 25%     34643.000000      22.000000     170.00000      63.000000
# 50%     68205.000000      25.000000     175.00000      70.000000
# 75%    102097.250000      28.000000     180.00000      75.000000
# max    135571.000000      97.000000     226.00000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# save updated data as csv file

athlete_new = athlete.to_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\athlete_new.csv")

# %%
# Displaying Region data 

Region.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# fill missing data 

Region.fillna({
    "region": Region["notes"]
},inplace= True)

# %%
Region.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# Saving file as csv
Region_new = Region.to_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\Region_new.csv")

# %%
# Displaying Population data
pd.set_option("display.max_columns()", None)
pop.head()
# Out:
#        Country Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965        1966  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     57715.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  10152331.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0   6309770.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0   1914573.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     19647.0
#
#          1967        1968        1969        1970        1971        1972  \
# ...

# %%
for col in pop.columns:
    missing_pct= np.mean(pop[col].isnull())
    print("{} - {}".format(col,missing_pct))
# Out:
# Country - 0.0
# Country Code - 0.0
# Indicator Name - 0.0
# Indicator Code - 0.0
# 1960 - 0.0
# 1961 - 0.0
# 1962 - 0.0
# 1963 - 0.0
# 1964 - 0.0
# 1965 - 0.0
# 1966 - 0.0
# 1967 - 0.0
# 1968 - 0.0
# 1969 - 0.0
# 1970 - 0.0
# 1971 - 0.0
# 1972 - 0.0
# 1973 - 0.0
# 1974 - 0.0
# 1975 - 0.0
# 1976 - 0.0
# 1977 - 0.0
# 1978 - 0.0
# 1979 - 0.0
# 1980 - 0.0
# 1981 - 0.0
# 1982 - 0.0
# 1983 - 0.0
# 1984 - 0.0
# 1985 - 0.0
# 1986 - 0.0
# 1987 - 0.0
# 1988 - 0.0
# 1989 - 0.0
# 1990 - 0.0
# 1991 - 0.0
# 1992 - 0.0
# 1993 - 0.0
# 1994 - 0.0
# 1995 - 0.0
# 1996 - 0.0
# 1997 - 0.0
# 1998 - 0.0
# 1999 - 0.0
# 2000 - 0.0
# 2001 - 0.0
# 2002 - 0.0
# 2003 - 0.0
# 2004 - 0.0
# 2005 - 0.0
# 2006 - 0.0
# 2007 - 0.0
# 2008 - 0.0
# 2009 - 0.0
# 2010 - 0.0
# 2011 - 0.0
# 2012 - 0.0
# 2013 - 0.0
# 2014 - 0.0
# 2015 - 0.0
# 2016 - 0.0

# %%
# filling missing data by linear interpolation

pop.interpolate(method="linear", inplace= True)

# %%
pop.head()
# Out:
#        Country Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965        1966  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     57715.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  10152331.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0   6309770.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0   1914573.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     19647.0
#
#          1967        1968        1969        1970        1971        1972  \
# ...

# %%
# save data as csv
pop_new =pop.to_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\pop_new.csv")

# %%
GDP.head()
# Out:
#    Last Updated Date     1/25/2018                NaN             NaN  \
# 0  Last Updated Date     1/25/2018                NaN             NaN
# 1                NaN           NaN                NaN             NaN
# 2       Country Name  Country Code     Indicator Name  Indicator Code
# 3        Afghanistan           AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 4            Albania           ALB  GDP (current US$)  NY.GDP.MKTP.CD
#
#            NaN          NaN          NaN          NaN          NaN  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       1960.0       1961.0       1962.0       1963.0       1964.0
# 3  537777811.0  548888896.0  546666678.0  751111191.0  800000044.0
# 4          NaN          NaN          NaN          NaN          NaN
#
#             NaN           NaN           NaN           NaN           NaN  \
# ...

# %%
# removing top rows and rename column on row
GDP.drop(index= [0,1],inplace=True)

# %%
GDP.head()
# Out:
#   Last Updated Date     1/25/2018                NaN             NaN  \
# 2      Country Name  Country Code     Indicator Name  Indicator Code
# 3       Afghanistan           AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 4           Albania           ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 5           Algeria           DZA  GDP (current US$)  NY.GDP.MKTP.CD
# 6    American Samoa           ASM  GDP (current US$)  NY.GDP.MKTP.CD
#
#             NaN           NaN           NaN           NaN           NaN  \
# 2  1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03  1.964000e+03
# 3  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 4           NaN           NaN           NaN           NaN           NaN
# 5  2.723649e+09  2.434777e+09  2.001469e+09  2.703015e+09  2.909352e+09
# 6           NaN           NaN           NaN           NaN           NaN
#
#             NaN           NaN           NaN           NaN           NaN  \
# ...

# %%
GDP.rename(columns= GDP.iloc[0],inplace= True)

# %%
GDP.drop(index=[2],inplace= True)

# %%
GDP.head()
# Out:
#   Last Updated Date 1/25/2018                NaN             NaN  \
# 3       Afghanistan       AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 4           Albania       ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 5           Algeria       DZA  GDP (current US$)  NY.GDP.MKTP.CD
# 6    American Samoa       ASM  GDP (current US$)  NY.GDP.MKTP.CD
# 7           Andorra       AND  GDP (current US$)  NY.GDP.MKTP.CD
#
#             NaN           NaN           NaN           NaN           NaN  \
# 3  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 4           NaN           NaN           NaN           NaN           NaN
# 5  2.723649e+09  2.434777e+09  2.001469e+09  2.703015e+09  2.909352e+09
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
#
#             NaN           NaN           NaN           NaN           NaN  \
# ...

# %%
# fill missing data by linear interpolation
sns.heatmap(GDP.isnull())
# Out:
# <AxesSubplot:>

# %%
GDP.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960.0            float64
# 1961.0            float64
# 1962.0            float64
# 1963.0            float64
# 1964.0            float64
# 1965.0            float64
# 1966.0            float64
# 1967.0            float64
# 1968.0            float64
# 1969.0            float64
# 1970.0            float64
# 1971.0            float64
# 1972.0            float64
# 1973.0            float64
# 1974.0            float64
# 1975.0            float64
# 1976.0            float64
# 1977.0            float64
# 1978.0            float64
# 1979.0            float64
# 1980.0            float64
# 1981.0            float64
# 1982.0            float64
# 1983.0            float64
# 1984.0            float64
# 1985.0            float64
# 1986.0            float64
# 1987.0            float64
# 1988.0            float64
# 1989.0            float64
# 1990.0            float64
# ...

# %%
# drop unnecessary columns

GDP.drop(columns="Indicator Code", inplace= True )

# %%
GDP.interpolate(method= "linear").head()
# Out:
#   Last Updated Date 1/25/2018                NaN             NaN  \
# 3       Afghanistan       AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 4           Albania       ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 5           Algeria       DZA  GDP (current US$)  NY.GDP.MKTP.CD
# 6    American Samoa       ASM  GDP (current US$)  NY.GDP.MKTP.CD
# 7           Andorra       AND  GDP (current US$)  NY.GDP.MKTP.CD
#
#             NaN           NaN           NaN           NaN           NaN  \
# 3  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 4  1.630713e+09  1.491833e+09  1.274068e+09  1.727063e+09  1.854676e+09
# 5  2.723649e+09  2.434777e+09  2.001469e+09  2.703015e+09  2.909352e+09
# 6  4.707361e+09  4.588712e+09  6.491296e+09  5.816837e+09  7.448531e+09
# 7  6.691073e+09  6.742646e+09  1.098112e+10  8.930658e+09  1.198771e+10
#
#             NaN           NaN           NaN           NaN           NaN  \
# ...

# %%
sns.heatmap(athlete.corr())
# Out:
# <AxesSubplot:>

# %%
 gdp_new.to_csv("C:\\Users\\VOID HEAD\\Desktop\\Portfolio Project\\Python Project\\gdp_new.csv")
